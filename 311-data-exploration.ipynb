# %%
import requests

# %%
url = 'https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$query=SELECT%0A%20%20%60unique_key%60%2C%0A%20%20%60created_date%60%2C%0A%20%20%60closed_date%60%2C%0A%20%20%60agency%60%2C%0A%20%20%60agency_name%60%2C%0A%20%20%60complaint_type%60%2C%0A%20%20%60descriptor%60%2C%0A%20%20%60location_type%60%2C%0A%20%20%60incident_zip%60%2C%0A%20%20%60incident_address%60%2C%0A%20%20%60street_name%60%2C%0A%20%20%60cross_street_1%60%2C%0A%20%20%60cross_street_2%60%2C%0A%20%20%60intersection_street_1%60%2C%0A%20%20%60intersection_street_2%60%2C%0A%20%20%60address_type%60%2C%0A%20%20%60city%60%2C%0A%20%20%60landmark%60%2C%0A%20%20%60facility_type%60%2C%0A%20%20%60status%60%2C%0A%20%20%60due_date%60%2C%0A%20%20%60resolution_description%60%2C%0A%20%20%60resolution_action_updated_date%60%2C%0A%20%20%60community_board%60%2C%0A%20%20%60bbl%60%2C%0A%20%20%60borough%60%2C%0A%20%20%60x_coordinate_state_plane%60%2C%0A%20%20%60y_coordinate_state_plane%60%2C%0A%20%20%60open_data_channel_type%60%2C%0A%20%20%60park_facility_name%60%2C%0A%20%20%60park_borough%60%2C%0A%20%20%60vehicle_type%60%2C%0A%20%20%60taxi_company_borough%60%2C%0A%20%20%60taxi_pick_up_location%60%2C%0A%20%20%60bridge_highway_name%60%2C%0A%20%20%60bridge_highway_direction%60%2C%0A%20%20%60road_ramp%60%2C%0A%20%20%60bridge_highway_segment%60%2C%0A%20%20%60latitude%60%2C%0A%20%20%60longitude%60%2C%0A%20%20%60location%60%2C%0A%20%20%60%3A%40computed_region_efsh_h5xi%60%2C%0A%20%20%60%3A%40computed_region_f5dn_yrer%60%2C%0A%20%20%60%3A%40computed_region_yeji_bk3q%60%2C%0A%20%20%60%3A%40computed_region_92fq_4b7q%60%2C%0A%20%20%60%3A%40computed_region_sbqj_enih%60%2C%0A%20%20%60%3A%40computed_region_7mpf_4k6g%60%0AWHERE%0A%20%20%60created_date%60%0A%20%20%20%20BETWEEN%20%222023-01-01T01%3A00%3A00%22%20%3A%3A%20floating_timestamp%0A%20%20%20%20AND%20%222024-02-20T16%3A58%3A07%22%20%3A%3A%20floating_timestamp%0AORDER%20BY%20%60created_date%60%20DESC%20NULL%20FIRST'
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
import pandas as pd

# %%
df = pd.read_csv('311_Service_Requests_from_2010_to_Present_20240220.csv')
df.head()
# Out:
# /var/folders/st/3g_y2gzx2qlcw80sfz6hkjk00000gn/T/ipykernel_27528/1840713876.py:1: DtypeWarning: Columns (8,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('311_Service_Requests_from_2010_to_Present_20240220.csv')
#    Unique Key            Created Date             Closed Date Agency  \
# 0    60353836  02/19/2024 12:00:00 PM                     NaN   DSNY
# 1    60352935  02/19/2024 12:00:00 PM  02/19/2024 12:00:00 PM   DSNY
# 2    60353835  02/19/2024 12:00:00 PM                     NaN   DSNY
# 3    60354741  02/19/2024 12:00:00 PM                     NaN   DSNY
# 4    60359268  02/19/2024 12:00:00 PM                     NaN   DSNY
#
#                 Agency Name     Complaint Type         Descriptor  \
# 0  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 1  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# ...

# %%
len(df['Complaint Type'].unique())
# Out:
# 217

# %%
new_df = df.groupby('Complaint Type').size().sort_values(ascending=False).reset_index(name='count')
new_df
# Out:
#               Complaint Type   count
# 0            Illegal Parking  542387
# 1        Noise - Residential  334029
# 2             HEAT/HOT WATER  299607
# 3           Blocked Driveway  190016
# 4    Noise - Street/Sidewalk  154042
# ..                       ...     ...
# 212          Quality of Life       1
# 213  Face Covering Violation       1
# 214                     SRDE       1
# 215           Unlicensed Dog       1
# 216    Executive Inspections       1
#
# [217 rows x 2 columns]

# %%
new_df.to_csv('complaints.csv', index=False)
print('done')
# Out:
# done

# %%
df[df['Complaint Type'] == 'Tattooing']
# Out:
#          Unique Key            Created Date Closed Date Agency  \
# 1260       60356484  02/18/2024 09:03:13 PM         NaN  DOHMH
# 18085      60337303  02/16/2024 01:04:25 PM         NaN  DOHMH
# 24019      60331677  02/15/2024 06:27:28 PM         NaN  DOHMH
# 24110      60336110  02/15/2024 06:15:09 PM         NaN  DOHMH
# 24147      60334982  02/15/2024 06:09:22 PM         NaN  DOHMH
# ...             ...                     ...         ...    ...
# 3640433    56433134  01/03/2023 10:19:30 PM         NaN  DOHMH
# 3640544    56426414  01/03/2023 10:00:47 PM         NaN  DOHMH
# 3640587    56434362  01/03/2023 09:50:51 PM         NaN  DOHMH
# 3648633    56424163  01/02/2023 10:17:10 PM         NaN  DOHMH
# 3650358    56424954  01/02/2023 04:41:49 PM         NaN  DOHMH
#
#                                      Agency Name Complaint Type  \
# 1260     Department of Health and Mental Hygiene      Tattooing
# 18085    Department of Health and Mental Hygiene      Tattooing
# ...

# %%
df_fireworks = df[df['Complaint Type'] == 'Illegal Fireworks']

# %%
df_fireworks.to_csv('fireworks_311.csv', index=False)
print('done')
# Out:
# done

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# During startup - Warning messages:
# 1: Setting LC_COLLATE failed, using "C"
# 2: Setting LC_TIME failed, using "C"
# 3: Setting LC_MESSAGES failed, using "C"
# 4: Setting LC_MONETARY failed, using "C"

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# library(tidycensus)
# library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# %%R
#
# df_fireworks <- read.csv('fireworks_311.csv')

# %%
# %%R
#
# #map df_fireworks onto a map
# df_fireworks %>%
#     ggplot(aes(x = Longitude, y = Latitude)) +
#     geom_point() +
#     coord_quickmap()
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: Removed 340 rows containing missing values (`geom_point()`).

# %%
#group by zip code
df_fireworks.groupby('Incident Zip').size().sort_values(ascending=False)
# Out:
# Incident Zip
# 11209.0    288
# 11372.0    261
# 10034.0    231
# 11226.0    227
# 10040.0    219
#           ...
# 11430.0      1
# 11239.0      1
# 10022.0      1
# 10005.0      1
# 10075.0      1
# Length: 174, dtype: int64

# %%
df_fireworks['Incident Zip'].value_counts().head(20)
# Out:
# Incident Zip
# 11209.0    288
# 11372.0    261
# 10034.0    231
# 11226.0    227
# 10040.0    219
# 10031.0    210
# 10032.0    210
# 11223.0    179
# 10312.0    169
# 10306.0    157
# 11220.0    154
# 10309.0    151
# 11368.0    147
# 11385.0    142
# 10468.0    140
# 10314.0    131
# 11377.0    131
# 10029.0    124
# 10452.0    120
# 10002.0    118
# Name: count, dtype: int64

# %%
df_asbestos = df[df['Complaint Type'] == 'Asbestos']
df_asbestos
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 1297       60359158  02/18/2024 08:58:42 PM                     NaN  DOHMH
# 1476       60355556  02/18/2024 08:17:22 PM                     NaN  DOHMH
# 3119       60352231  02/18/2024 03:29:00 PM                     NaN    DEP
# 4210       60353941  02/18/2024 12:35:00 PM                     NaN    DEP
# 5459       60356596  02/18/2024 09:29:00 AM                     NaN    DEP
# ...             ...                     ...                     ...    ...
# 3646749    56429486  01/03/2023 08:29:00 AM  01/03/2023 02:45:00 PM    DEP
# 3646962    56428281  01/03/2023 07:53:00 AM  01/04/2023 09:35:00 AM    DEP
# 3649400    56503858  01/02/2023 07:38:28 PM  01/04/2023 03:30:00 PM  DOHMH
# 3651769    56422920  01/02/2023 01:14:13 PM  01/04/2023 09:53:02 AM  DOHMH
# 3653065    56424689  01/02/2023 10:31:43 AM  01/03/2023 02:08:47 PM  DOHMH
#
#                                      Agency Name Complaint Type  \
# ...

# %%
df_asbestos[df_asbestos['Incident Zip'] == 10025.0]
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 226657     60114401  01/23/2024 12:46:22 PM  01/23/2024 04:50:48 PM  DOHMH
# 404427     59927931  01/04/2024 02:00:41 PM  01/16/2024 04:54:58 PM  DOHMH
# 415740     59915080  01/03/2024 11:23:00 AM  01/03/2024 02:00:00 PM    DEP
# 535830     59791218  12/19/2023 09:43:20 AM  12/19/2023 11:04:06 AM  DOHMH
# 572012     59754540  12/15/2023 09:16:30 AM  12/18/2023 12:37:19 PM  DOHMH
# 582149     59745217  12/14/2023 09:23:00 AM  12/14/2023 01:40:00 PM    DEP
# 634433     59682461  12/08/2023 04:48:11 PM  12/20/2023 12:20:00 PM  DOHMH
# 648629     59664532  12/07/2023 10:05:00 AM  12/08/2023 09:35:00 AM    DEP
# 675528     59641144  12/04/2023 04:53:00 PM  12/05/2023 10:15:00 AM    DEP
# 772824     59537893  11/24/2023 09:19:59 AM  12/15/2023 09:00:00 AM  DOHMH
# 906715     59375705  11/09/2023 09:59:00 AM  11/09/2023 10:10:00 AM    DEP
# ...

# %%
df_asbestos['Incident Zip'].value_counts().head(20)
# Out:
# Incident Zip
# 10025.0    47
# 10002.0    39
# 11207.0    33
# 10036.0    31
# 10458.0    28
# 10019.0    27
# 11222.0    27
# 10463.0    25
# 11215.0    24
# 11231.0    22
# 11233.0    22
# 10024.0    22
# 11375.0    21
# 11238.0    21
# 11223.0    20
# 11385.0    19
# 11217.0    19
# 11206.0    19
# 11211.0    18
# 10033.0    17
# Name: count, dtype: int64

# %%
df_asbestos.to_csv('asbestos_311.csv', index=False)

# %%
# %%R
#
# df_asbestos <- read.csv('asbestos_311.csv')

# %%
# %%R
#
# #map df_asbestos onto a map
# df_asbestos %>%
#     ggplot(aes(x = Longitude, y = Latitude)) +
#     geom_point() +
#     coord_quickmap()
# Out:
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: Removed 1 rows containing missing values (`geom_point()`).

# %%
df_graffiti = df[df['Complaint Type'] == 'Graffiti']
df_graffiti
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 2805       60353972  02/18/2024 04:18:55 PM                     NaN   DSNY
# 3009       60354094  02/18/2024 03:47:37 PM  02/19/2024 02:22:23 AM   DSNY
# 3044       60356758  02/18/2024 03:43:26 PM                     NaN   DSNY
# 3046       60352373  02/18/2024 03:42:21 PM                     NaN   DSNY
# 3051       60358512  02/18/2024 03:41:16 PM                     NaN   DSNY
# ...             ...                     ...                     ...    ...
# 3656386    56412585  01/01/2023 06:48:37 PM  04/28/2023 12:00:00 AM   DSNY
# 3656545    56413527  01/01/2023 06:16:11 PM  05/18/2023 12:00:00 AM   DSNY
# 3656551    56412534  01/01/2023 06:15:08 PM  01/11/2024 02:03:33 PM   DSNY
# 3658180    56415228  01/01/2023 12:31:28 PM  01/01/2023 02:18:00 PM   NYPD
# 3658638    56412549  01/01/2023 10:42:41 AM  01/01/2023 11:37:20 AM   NYPD
#
#                              Agency Name Complaint Type  \
# ...

# %%
df_graffiti['Incident Zip'].value_counts().head(20)
# Out:
# Incident Zip
# 11211.0    1309
# 10002.0    1138
# 11220.0     639
# 11237.0     610
# 11206.0     607
# 11222.0     564
# 11249.0     432
# 11221.0     378
# 10013.0     339
# 10312.0     337
# 11232.0     320
# 11214.0     272
# 11207.0     264
# 11215.0     256
# 11204.0     242
# 10009.0     218
# 10462.0     204
# 11385.0     198
# 10012.0     187
# 10029.0     180
# Name: count, dtype: int64

# %%
# incident zip 11211 to a new df
df_graffiti_wburg = df_graffiti[df_graffiti['Incident Zip'] == 11211.0]
df_graffiti_wburg
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 9807       60351430  02/17/2024 04:28:00 PM                     NaN   DSNY
# 9813       60345623  02/17/2024 04:27:05 PM                     NaN   DSNY
# 9823       60348056  02/17/2024 04:26:30 PM                     NaN   DSNY
# 9826       60348256  02/17/2024 04:26:15 PM  02/18/2024 02:22:24 AM   DSNY
# 16786      60343347  02/16/2024 03:50:34 PM                     NaN   DSNY
# ...             ...                     ...                     ...    ...
# 3599883    56477504  01/09/2023 08:20:50 AM                     NaN   DSNY
# 3599898    56480217  01/09/2023 08:18:46 AM  04/20/2023 12:00:00 AM   DSNY
# 3602703    56476031  01/08/2023 06:55:45 PM  01/08/2023 07:13:42 PM   NYPD
# 3621598    56460175  01/06/2023 08:37:23 AM  05/16/2023 12:00:00 AM   DSNY
# 3642426    56431293  01/03/2023 04:25:44 PM  04/27/2023 12:00:00 AM   DSNY
#
#                              Agency Name Complaint Type  \
# ...

# %%
# unique incident addresses counts
df_graffiti_wburg['Incident Address'].value_counts().head(20)
# Out:
# Incident Address
# 505 UNION AVENUE         9
# 54 AINSLIE STREET        8
# 441 KEAP STREET          7
# 364 GRAHAM AVENUE        7
# 485 GRAND STREET         7
# 454 UNION AVENUE         7
# 195 NORTH    7 STREET    6
# 335 SOUTH    2 STREET    6
# 294 GRAHAM AVENUE        6
# 328 GRAHAM AVENUE        6
# 392 LEONARD STREET       5
# 422 UNION AVENUE         5
# 773 GRAND STREET         5
# 575 LORIMER STREET       5
# 575 DRIGGS AVENUE        5
# 371 UNION AVENUE         5
# 172 GRAND STREET         4
# 772 GRAND STREET         4
# 297 MEEKER AVENUE        4
# 373 SOUTH    1 STREET    4
# Name: count, dtype: int64

# %%
#incident address has string with "UNION AVE"
df_graffiti_wburg[df_graffiti_wburg['Incident Address'].str.contains('505 UNION AVE')]
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 400813     59924453  01/04/2024 09:17:57 PM  01/05/2024 12:00:00 AM   DSNY
# 975843     59292511  11/02/2023 03:00:07 AM  11/02/2023 03:00:07 AM   DSNY
# 1099775    59176897  10/20/2023 06:31:03 AM  10/23/2023 12:00:00 AM   DSNY
# 1412737    58853076  09/18/2023 12:13:50 PM  09/19/2023 12:00:00 AM   DSNY
# 1534623    58720312  09/05/2023 02:03:05 PM  09/07/2023 12:00:00 AM   DSNY
# 1579623    58675798  08/31/2023 11:59:42 AM  09/01/2023 12:00:00 AM   DSNY
# 1768629    58472321  08/10/2023 04:17:01 PM  08/11/2023 12:00:00 AM   DSNY
# 1860926    58372861  07/31/2023 03:25:13 PM  08/07/2023 12:00:00 AM   DSNY
# 3200754    56919938  02/28/2023 08:11:00 AM  04/26/2023 12:00:00 AM   DSNY
#
#                       Agency Name Complaint Type Descriptor Location Type  \
# 400813   Department of Sanitation       Graffiti   Graffiti     Comercial
# ...

# %%
#incident address is 54 AINSLIE STREET
df_graffiti_wburg[df_graffiti_wburg['Incident Address'].str.contains('54 AINSLIE STREET')]
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 129517     60224386  02/03/2024 06:12:41 AM                     NaN   DSNY
# 975753     59310689  11/02/2023 03:50:03 AM  11/03/2023 12:00:00 AM   DSNY
# 1472723    58791762  09/12/2023 07:49:25 AM  10/30/2023 12:00:00 AM   DSNY
# 1591551    58665671  08/30/2023 05:20:01 AM  09/01/2023 12:00:00 AM   DSNY
# 1764947    58482554  08/11/2023 07:15:45 AM  08/14/2023 12:00:00 AM   DSNY
# 1912624    58324197  07/26/2023 05:59:43 AM  08/01/2023 12:00:00 AM   DSNY
# 2512043    57664746  05/20/2023 10:25:51 PM  05/24/2023 12:00:00 AM   DSNY
# 3200777    56922565  02/28/2023 08:06:26 AM  05/15/2023 12:00:00 AM   DSNY
#
#                       Agency Name Complaint Type Descriptor Location Type  \
# 129517   Department of Sanitation       Graffiti   Graffiti           NaN
# 975753   Department of Sanitation       Graffiti   Graffiti           NaN
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
#export df_graffiti to csv
df_graffiti.to_csv('graffiti_311.csv', index=False)
